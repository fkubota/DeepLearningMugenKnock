# %% [markdown]
# - LeNet

# %%
import torch
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # Prepare the Dataset
# - dataloader の作成

# %%
path = './../Dataset/train/images/'

# %% [markdown]
# ---
# **Image Check**

# %%
path01 = './../Dataset/train/images/akahara/akahara_0001.jpg' 
path02 = './../Dataset/train/images/madara/madara_0001.jpg' 
path_list = [path01, path02]
title_list = ['akahara', 'madara']

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 10))

for i, path in enumerate(path_list):
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    axs[i].imshow(img)
    axs[i].set_title(title_list[i])

# %% [markdown]
# ---
# **前処理を定義**

# %%
data_transforms = {'train': transforms.Compose}
